# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanshu0055/ML/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

path = kagglehub.dataset_download("parvmodi/cgpa-vs-package-in-lpa")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\shiva\.cache\kagglehub\datasets\parvmodi\cgpa-vs-package-in-lpa\versions\1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data=pd.read_csv('placement.csv')

print(data.head())

plt.scatter(data['cgpa'],data['package'])
plt.xlabel('CGPA')
plt.ylabel('Package in LPA')
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# Text(0, 0.5, 'Package in LPA')

# %%
X=data.iloc[:,0:1]
Y=data.iloc[:,-1]
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

from sklearn.linear_model import LinearRegression

lr=LinearRegression()

lr.fit(X_train,Y_train)

# print(X_test[0])
print(X_test.iloc[0].values.reshape(-1,1))
print(lr.predict(X_test.iloc[0].values.reshape(-1,1)))
# Out:
# [[8.58]]
# [3.89111601]
# c:\Users\shiva\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
data=pd.read_csv('Boston.csv')
# print(data.describe())
print(data.keys())
X=data.iloc[:,0:-1]
Y=data.iloc[:,-1]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
lr=LinearRegression()
lr.fit(X_train,Y_train)
print(lr.predict(X_test.iloc[0].values.reshape(1,-1)))
print("Accuracy is",lr.score(X_test,Y_test)*100)
data.info()
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')
# [28.97335364]
# Accuracy is 66.59408703343053
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
# ...
